# %%
from bcs_rs import BCSServer

# %%
server = BCSServer()

conn = await server.connect(addr="localhost", port=5577, use_curve=False)

# %%
from time import perf_counter

start = perf_counter()
await conn.bcs_request("StartAcquire", {"time": 0.002, "name": "Axis Photonique"})
