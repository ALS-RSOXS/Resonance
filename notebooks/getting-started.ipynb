# %%
from resonance.api import Beamline

# Allways a good idea to import these for working with your data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We can connect to the beamline server using the `Beamline` class

# %%
bl = await Beamline.create()

# %% [markdown]
# Let's deal with some common beamline operations that we will want to have access to

# %%
display(await bl.ai.read("Photodiode", "Izero"))
display(await bl.motors.read("Sample X", "Sample Y", "Sample Z"))
# Out:
# {'Photodiode': [-0.111046825033455], 'Izero': [-0.129960034578217]}
# {'Sample X': MotorState(position=34.033, goal=34.033, status=67632, time=3857750304.79072),
#  'Sample Y': MotorState(position=4.008, goal=4.008, status=65568, time=3857750304.79172),
#  'Sample Z': MotorState(position=-0.0, goal=0.0, status=65576, time=3857750304.79172)}

# %%
display(await bl.dio.read("Shutter Output"))
# Out:
# {'Shutter Output': False}
